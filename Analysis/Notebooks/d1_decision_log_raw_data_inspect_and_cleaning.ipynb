# %%
import sys
from pathlib import Path

def find_project_root(markers=("src", "Data", "Notebooks")):
    current_path = Path.cwd().resolve()

    for path in [current_path] + list(current_path.parents):
        has_all_markers = all((path / marker).exists() for marker in markers)
        if has_all_markers:
            return path

    raise RuntimeError(f"Project root could not be found from: {current_path}")

project_root = find_project_root()
src_path = project_root / "src"

if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

import paths as P

# %%
import json
import pandas as pd

json_files = list(P.decision_logs_raw_dir.rglob("*.json"))

print("Number of JSON files found:")
print(len(json_files))
print()

print("First 5 files:")
for file in json_files[:5]:
    print(file)
# Out:
# Number of JSON files found:
# 137
#
# First 5 files:
# F:\scenario-based cyber security management simulation\ISMSimulationGame\ISMSimulationGame\Analysis\Data\Decision_Logs\Raw\CT4010 afternoon decision logs\ISM_Decision_Log_run_1776087643609_b1186f57813e18.json
# F:\scenario-based cyber security management simulation\ISMSimulationGame\ISMSimulationGame\Analysis\Data\Decision_Logs\Raw\CT4010 afternoon decision logs\ISM_Decision_Log_run_1776087849461_b8982278927ba8.json
# F:\scenario-based cyber security management simulation\ISMSimulationGame\ISMSimulationGame\Analysis\Data\Decision_Logs\Raw\CT4010 afternoon decision logs\ISM_Decision_Log_run_1776087894772_fbccd276826a48.json
# F:\scenario-based cyber security management simulation\ISMSimulationGame\ISMSimulationGame\Analysis\Data\Decision_Logs\Raw\CT4010 afternoon decision logs\ISM_Decision_Log_run_1776087905071_cea20dd6486ef8.json
# F:\scenario-based cyber security management simulation\ISMSimulationGame\ISMSimulationGame\Analysis\Data\Decision_Logs\Raw\CT4010 afternoon decision logs\ISM_Decision_Log_run_1776087967149_6a95cec5293b68.json

# %%
import re

# find all json files inside all class folders under Raw
json_files = sorted(P.decision_logs_raw_dir.rglob("*.json"))

print(f"JSON files found: {len(json_files)}")
for file in json_files[:5]:
    print(file)

all_rows = []

def parse_folder_info(folder_name):
    folder_clean = folder_name.strip()

    module_match = re.search(r"(CT\d+)", folder_clean, flags=re.IGNORECASE)
    module_code = module_match.group(1).upper() if module_match else None

    folder_lower = folder_clean.lower()
    if "morning" in folder_lower:
        session_time = "Morning"
    elif "afternoon" in folder_lower:
        session_time = "Afternoon"
    else:
        session_time = "Not specified"

    return module_code, session_time

for file in json_files:
    with open(file, "r", encoding="utf-8") as f:
        data = json.load(f)

    source_folder = file.parent.name
    source_file = file.name
    module_code, session_time = parse_folder_info(source_folder)

    run_id = data.get("run_id")
    sent_at = data.get("sent_at")

    final_scores = data.get("finalScores", {})
    decisions = data.get("decisionLog", [])

    if not isinstance(decisions, list):
        decisions = []

    n_decisions = len(decisions)
    completed_run = n_decisions == 15
    ended_early = n_decisions < 15

    # if a file has no decisions, still keep one row with top-level fields
    if n_decisions == 0:
        row = {
            "source_folder": source_folder,
            "module_code": module_code,
            "session_time": session_time,
            "source_file": source_file,

            "run_id": run_id,
            "sent_at": sent_at,

            "finalScores_budget": final_scores.get("budget"),
            "finalScores_reputation": final_scores.get("reputation"),
            "finalScores_security": final_scores.get("security"),
            "finalScores_morale": final_scores.get("morale"),

            "decision_order": None,
            "decisionLog_scenario": None,
            "decisionLog_choice": None,
            "decisionLog_outcome": None,
            "decisionLog_timestamp": None,

            "decisionLog_effects_budget": None,
            "decisionLog_effects_reputation": None,
            "decisionLog_effects_security": None,
            "decisionLog_effects_morale": None,

            "n_decisions": n_decisions,
            "completed_run": completed_run,
            "ended_early": ended_early
        }
        all_rows.append(row)

    # normal case: one row per decision
    for i, d in enumerate(decisions, start=1):
        effects = d.get("effects", {})

        row = {
            "source_folder": source_folder,
            "module_code": module_code,
            "session_time": session_time,
            "source_file": source_file,

            "run_id": run_id,
            "sent_at": sent_at,

            "finalScores_budget": final_scores.get("budget"),
            "finalScores_reputation": final_scores.get("reputation"),
            "finalScores_security": final_scores.get("security"),
            "finalScores_morale": final_scores.get("morale"),

            "decision_order": i,
            "decisionLog_scenario": d.get("scenario"),
            "decisionLog_choice": d.get("choice"),
            "decisionLog_outcome": d.get("outcome"),
            "decisionLog_timestamp": d.get("timestamp"),

            "decisionLog_effects_budget": effects.get("budget"),
            "decisionLog_effects_reputation": effects.get("reputation"),
            "decisionLog_effects_security": effects.get("security"),
            "decisionLog_effects_morale": effects.get("morale"),

            "n_decisions": n_decisions,
            "completed_run": completed_run,
            "ended_early": ended_early
        }

        all_rows.append(row)

master_df = pd.DataFrame(all_rows)

master_file = P.decision_logs_interim_dir / "master_decision_logs.csv"
master_df.to_csv(master_file, index=False)

print("\nMaster dataset created:")
print(master_file)
print("Shape:", master_df.shape)

print("\nColumns:")
print(master_df.columns.tolist())

print("\nSource folders found:")
print(master_df["source_folder"].drop_duplicates().tolist())

print("\nCompleted vs ended early:")
print(master_df[["completed_run", "ended_early"]].drop_duplicates())

print("\nFirst 5 rows:")
print(master_df.head())
# Out:
# JSON files found: 137
# F:\scenario-based cyber security management simulation\ISMSimulationGame\ISMSimulationGame\Analysis\Data\Decision_Logs\Raw\CT4010 afternoon decision logs\ISM_Decision_Log_run_1776087643609_b1186f57813e18.json
# F:\scenario-based cyber security management simulation\ISMSimulationGame\ISMSimulationGame\Analysis\Data\Decision_Logs\Raw\CT4010 afternoon decision logs\ISM_Decision_Log_run_1776087849461_b8982278927ba8.json
# F:\scenario-based cyber security management simulation\ISMSimulationGame\ISMSimulationGame\Analysis\Data\Decision_Logs\Raw\CT4010 afternoon decision logs\ISM_Decision_Log_run_1776087894772_fbccd276826a48.json
# F:\scenario-based cyber security management simulation\ISMSimulationGame\ISMSimulationGame\Analysis\Data\Decision_Logs\Raw\CT4010 afternoon decision logs\ISM_Decision_Log_run_1776087905071_cea20dd6486ef8.json
# F:\scenario-based cyber security management simulation\ISMSimulationGame\ISMSimulationGame\Analysis\Data\Decision_Logs\Raw\CT4010 afternoon decision logs\ISM_Decision_Log_run_1776087967149_6a95cec5293b68.json
#
# Master dataset created:
# F:\scenario-based cyber security management simulation\ISMSimulationGame\ISMSimulationGame\Analysis\Data\Decision_Logs\Interim\master_decision_logs.csv
# Shape: (2024, 22)
#
# Columns:
# ['source_folder', 'module_code', 'session_time', 'source_file', 'run_id', 'sent_at', 'finalScores_budget', 'finalScores_reputation', 'finalScores_security', 'finalScores_morale', 'decision_order', 'decisionLog_scenario', 'decisionLog_choice', 'decisionLog_outcome', 'decisionLog_timestamp', 'decisionLog_effects_budget', 'decisionLog_effects_reputation', 'decisionLog_effects_security', 'decisionLog_effects_morale', 'n_decisions', 'completed_run', 'ended_early']
#
# Source folders found:
# ['CT4010 afternoon decision logs', 'CT4010 Morning Decision Logs', 'CT5056 Afternoon Decision Logs', 'CT5056 Morning Decision Logs', 'CT6033 Decision Logs', 'CT7074 Decision Logs']
#
# Completed vs ended early:
#      completed_run  ended_early
# 0             True        False
# 180          False         True
#
# First 5 rows:
#                     source_folder module_code session_time  \
# 0  CT4010 afternoon decision logs      CT4010    Afternoon
# 1  CT4010 afternoon decision logs      CT4010    Afternoon
# 2  CT4010 afternoon decision logs      CT4010    Afternoon
# 3  CT4010 afternoon decision logs      CT4010    Afternoon
# 4  CT4010 afternoon decision logs      CT4010    Afternoon
#
#                                          source_file  \
# 0  ISM_Decision_Log_run_1776087643609_b1186f57813...
# 1  ISM_Decision_Log_run_1776087643609_b1186f57813...
# 2  ISM_Decision_Log_run_1776087643609_b1186f57813...
# 3  ISM_Decision_Log_run_1776087643609_b1186f57813...
# 4  ISM_Decision_Log_run_1776087643609_b1186f57813...
#
#                              run_id                   sent_at  \
# 0  run_1776087643609_b1186f57813e18  2026-04-13T13:40:43.609Z
# 1  run_1776087643609_b1186f57813e18  2026-04-13T13:40:43.609Z
# 2  run_1776087643609_b1186f57813e18  2026-04-13T13:40:43.609Z
# 3  run_1776087643609_b1186f57813e18  2026-04-13T13:40:43.609Z
# 4  run_1776087643609_b1186f57813e18  2026-04-13T13:40:43.609Z
#
#    finalScores_budget  finalScores_reputation  finalScores_security  \
# 0              276000                     125                   178
# 1              276000                     125                   178
# 2              276000                     125                   178
# 3              276000                     125                   178
# 4              276000                     125                   178
#
#    finalScores_morale  ...           decisionLog_choice  \
# 0                 113  ...   Negotiate While Recovering
# 1                 113  ...    Move to Third-Party Cloud
# 2                 113  ...         Phased Access Review
# 3                 113  ...  Apply Temporary Mitigations
# 4                 113  ...    Optional Training Modules
#
#                                  decisionLog_outcome  \
# 0  <strong>Security:</strong> remains stable beca...
# 1  <strong>Security:</strong> increases because c...
# 2  <strong>Security:</strong> increases moderatel...
# 3  <strong>Security:</strong> increases moderatel...
# 4  <strong>Security:</strong> increases slightly ...
#
#       decisionLog_timestamp decisionLog_effects_budget  \
# 0  2026-04-13T13:35:32.447Z                    -120000
# 1  2026-04-13T13:35:53.838Z                      25000
# 2  2026-04-13T13:36:15.658Z                     -22000
# 3  2026-04-13T13:36:40.937Z                     -30000
# 4  2026-04-13T13:37:01.639Z                      10000
#
#   decisionLog_effects_reputation  decisionLog_effects_security  \
# 0                            -18                             0
# 1                              2                             4
# 2                              6                             8
# 3                              3                             8
# 4                              1                             2
#
#    decisionLog_effects_morale  n_decisions  completed_run  ended_early
# 0                         -10           15           True        False
# 1                           1           15           True        False
# 2                           4           15           True        False
# 3                           1           15           True        False
# 4                           1           15           True        False
#
# [5 rows x 22 columns]

# %%
#load the master dataset
master_file = P.decision_logs_interim_dir / "master_decision_logs.csv"
master_df = pd.read_csv(master_file)

print("Master dataset shape:")
print(master_df.shape)
master_df.head()
# Out:
# Master dataset shape:
# (2024, 22)
#                     source_folder module_code session_time  \
# 0  CT4010 afternoon decision logs      CT4010    Afternoon
# 1  CT4010 afternoon decision logs      CT4010    Afternoon
# 2  CT4010 afternoon decision logs      CT4010    Afternoon
# 3  CT4010 afternoon decision logs      CT4010    Afternoon
# 4  CT4010 afternoon decision logs      CT4010    Afternoon
#
#                                          source_file  \
# 0  ISM_Decision_Log_run_1776087643609_b1186f57813...
# 1  ISM_Decision_Log_run_1776087643609_b1186f57813...
# 2  ISM_Decision_Log_run_1776087643609_b1186f57813...
# 3  ISM_Decision_Log_run_1776087643609_b1186f57813...
# 4  ISM_Decision_Log_run_1776087643609_b1186f57813...
#
#                              run_id                   sent_at  \
# 0  run_1776087643609_b1186f57813e18  2026-04-13T13:40:43.609Z
# 1  run_1776087643609_b1186f57813e18  2026-04-13T13:40:43.609Z
# 2  run_1776087643609_b1186f57813e18  2026-04-13T13:40:43.609Z
# 3  run_1776087643609_b1186f57813e18  2026-04-13T13:40:43.609Z
# 4  run_1776087643609_b1186f57813e18  2026-04-13T13:40:43.609Z
#
#    finalScores_budget  finalScores_reputation  finalScores_security  \
# 0              276000                     125                   178
# 1              276000                     125                   178
# 2              276000                     125                   178
# 3              276000                     125                   178
# 4              276000                     125                   178
#
#    finalScores_morale  ...           decisionLog_choice  \
# 0                 113  ...   Negotiate While Recovering
# 1                 113  ...    Move to Third-Party Cloud
# 2                 113  ...         Phased Access Review
# 3                 113  ...  Apply Temporary Mitigations
# 4                 113  ...    Optional Training Modules
#
#                                  decisionLog_outcome  \
# 0  <strong>Security:</strong> remains stable beca...
# 1  <strong>Security:</strong> increases because c...
# 2  <strong>Security:</strong> increases moderatel...
# 3  <strong>Security:</strong> increases moderatel...
# 4  <strong>Security:</strong> increases slightly ...
#
#       decisionLog_timestamp decisionLog_effects_budget  \
# 0  2026-04-13T13:35:32.447Z                    -120000
# 1  2026-04-13T13:35:53.838Z                      25000
# 2  2026-04-13T13:36:15.658Z                     -22000
# 3  2026-04-13T13:36:40.937Z                     -30000
# 4  2026-04-13T13:37:01.639Z                      10000
#
#   decisionLog_effects_reputation  decisionLog_effects_security  \
# 0                            -18                             0
# 1                              2                             4
# 2                              6                             8
# 3                              3                             8
# 4                              1                             2
#
#    decisionLog_effects_morale  n_decisions  completed_run  ended_early
# 0                         -10           15           True        False
# 1                           1           15           True        False
# 2                           4           15           True        False
# 3                           1           15           True        False
# 4                           1           15           True        False
#
# [5 rows x 22 columns]

# %%
#check columns and data types
print("Columns:")
print(master_df.columns.tolist())
print()

print("Data types:")
print(master_df.dtypes)
# Out:
# Columns:
# ['source_folder', 'module_code', 'session_time', 'source_file', 'run_id', 'sent_at', 'finalScores_budget', 'finalScores_reputation', 'finalScores_security', 'finalScores_morale', 'decision_order', 'decisionLog_scenario', 'decisionLog_choice', 'decisionLog_outcome', 'decisionLog_timestamp', 'decisionLog_effects_budget', 'decisionLog_effects_reputation', 'decisionLog_effects_security', 'decisionLog_effects_morale', 'n_decisions', 'completed_run', 'ended_early']
#
# Data types:
# source_folder                     object
# module_code                       object
# session_time                      object
# source_file                       object
# run_id                            object
# sent_at                           object
# finalScores_budget                 int64
# finalScores_reputation             int64
# finalScores_security               int64
# finalScores_morale                 int64
# decision_order                     int64
# decisionLog_scenario              object
# decisionLog_choice                object
# decisionLog_outcome               object
# decisionLog_timestamp             object
# decisionLog_effects_budget         int64
# decisionLog_effects_reputation     int64
# decisionLog_effects_security       int64
# decisionLog_effects_morale         int64
# n_decisions                        int64
# completed_run                       bool
# ended_early                         bool
# dtype: object

# %%
# Check for missing values
missing_summary = master_df.isna().sum().sort_values(ascending=False)

print("Missing values by column:")
print(missing_summary)
# Out:
# Missing values by column:
# source_folder                     0
# module_code                       0
# session_time                      0
# source_file                       0
# run_id                            0
# sent_at                           0
# finalScores_budget                0
# finalScores_reputation            0
# finalScores_security              0
# finalScores_morale                0
# decision_order                    0
# decisionLog_scenario              0
# decisionLog_choice                0
# decisionLog_outcome               0
# decisionLog_timestamp             0
# decisionLog_effects_budget        0
# decisionLog_effects_reputation    0
# decisionLog_effects_security      0
# decisionLog_effects_morale        0
# n_decisions                       0
# completed_run                     0
# ended_early                       0
# dtype: int64

# %%
# missing values in key columns
key_cols = [
    "source_folder",
    "module_code",
    "session_time",
    "source_file",
    "run_id",
    "sent_at",
    "decision_order",
    "decisionLog_scenario",
    "decisionLog_choice",
    "decisionLog_outcome",
    "decisionLog_timestamp",
    "decisionLog_effects_budget",
    "decisionLog_effects_reputation",
    "decisionLog_effects_security",
    "decisionLog_effects_morale"
]

print("Missing values in key columns:")
print(master_df[key_cols].isna().sum())
# Out:
# Missing values in key columns:
# source_folder                     0
# module_code                       0
# session_time                      0
# source_file                       0
# run_id                            0
# sent_at                           0
# decision_order                    0
# decisionLog_scenario              0
# decisionLog_choice                0
# decisionLog_outcome               0
# decisionLog_timestamp             0
# decisionLog_effects_budget        0
# decisionLog_effects_reputation    0
# decisionLog_effects_security      0
# decisionLog_effects_morale        0
# dtype: int64

# %%
# Check for duplicates
print("Exact duplicate rows:")
print(master_df.duplicated().sum())
# Out:
# Exact duplicate rows:
# 0

# %%
# Check for duplicates based on run_id and decision_order
decision_key = ["run_id", "decision_order"]
print("Duplicate run_id + decision_order rows:")
print(master_df.duplicated(subset=decision_key).sum())
# Out:
# Duplicate run_id + decision_order rows:
# 0

# %%
# Summary of unique runs and total rows
print("Unique runs:")
print(master_df["run_id"].nunique())
print()

print("Total rows:")
print(len(master_df))
print()

run_summary = master_df[["run_id", "n_decisions"]].drop_duplicates()
print("Sum of n_decisions across unique runs:")
print(run_summary["n_decisions"].sum())
# Out:
# Unique runs:
# 137
#
# Total rows:
# 2024
#
# Sum of n_decisions across unique runs:
# 2024

# %%
# Distribution of runs and rows by source folder
print("Runs by source folder:")
print(master_df[["run_id", "source_folder"]].drop_duplicates()["source_folder"].value_counts())
print()

print("Rows by source folder:")
print(master_df["source_folder"].value_counts())
# Out:
# Runs by source folder:
# source_folder
# CT4010 Morning Decision Logs      37
# CT4010 afternoon decision logs    33
# CT5056 Afternoon Decision Logs    28
# CT5056 Morning Decision Logs      16
# CT6033 Decision Logs              15
# CT7074 Decision Logs               8
# Name: count, dtype: int64
#
# Rows by source folder:
# source_folder
# CT4010 Morning Decision Logs      540
# CT4010 afternoon decision logs    487
# CT5056 Afternoon Decision Logs    416
# CT5056 Morning Decision Logs      238
# CT6033 Decision Logs              224
# CT7074 Decision Logs              119
# Name: count, dtype: int64

# %%
# Check completed vs ended early
run_status = master_df[["run_id", "n_decisions", "completed_run", "ended_early"]].drop_duplicates()

print("Run status counts:")
print(run_status[["completed_run", "ended_early"]].value_counts())
print()

print("Distribution of n_decisions:")
print(run_status["n_decisions"].value_counts().sort_index())
# Out:
# Run status counts:
# completed_run  ended_early
# True           False          126
# False          True            11
# Name: count, dtype: int64
#
# Distribution of n_decisions:
# n_decisions
# 10      1
# 11      3
# 12      2
# 13      3
# 14      2
# 15    126
# Name: count, dtype: int64

# %%
# Check decision order consistency
decision_order_check = (
    master_df.groupby("run_id")["decision_order"]
    .agg(["min", "max", "nunique"])
    .reset_index()
)

decision_order_check["expected_ok"] = (
    (decision_order_check["min"] == 1) &
    (decision_order_check["max"] == decision_order_check["nunique"])
)

print("Decision order problems:")
print((~decision_order_check["expected_ok"]).sum())

decision_order_check[~decision_order_check["expected_ok"]].head(20)
# Out:
# Decision order problems:
# 0
# Empty DataFrame
# Columns: [run_id, min, max, nunique, expected_ok]
# Index: []

# %%
# Check for blank strings in text columns
text_cols = [
    "decisionLog_scenario",
    "decisionLog_choice",
    "decisionLog_outcome"
]

for col in text_cols:
    blank_count = master_df[col].astype(str).str.strip().eq("").sum()
    print(f"{col} blank strings: {blank_count}")
# Out:
# decisionLog_scenario blank strings: 0
# decisionLog_choice blank strings: 0
# decisionLog_outcome blank strings: 0

# %%
# Check effect columns are numeric
effect_cols = [
    "decisionLog_effects_budget",
    "decisionLog_effects_reputation",
    "decisionLog_effects_security",
    "decisionLog_effects_morale"
]

print(master_df[effect_cols].dtypes)
print()

print("Non-numeric check after coercion:")
for col in effect_cols:
    converted = pd.to_numeric(master_df[col], errors="coerce")
    print(col, "non-numeric values:", converted.isna().sum() - master_df[col].isna().sum())
# Out:
# decisionLog_effects_budget        int64
# decisionLog_effects_reputation    int64
# decisionLog_effects_security      int64
# decisionLog_effects_morale        int64
# dtype: object
#
# Non-numeric check after coercion:
# decisionLog_effects_budget non-numeric values: 0
# decisionLog_effects_reputation non-numeric values: 0
# decisionLog_effects_security non-numeric values: 0
# decisionLog_effects_morale non-numeric values: 0

# %%
# check final score columns are numeric
final_score_cols = [
    "finalScores_budget",
    "finalScores_reputation",
    "finalScores_security",
    "finalScores_morale"
]

for col in final_score_cols:
    master_df[col] = pd.to_numeric(master_df[col], errors="coerce")

print(master_df[final_score_cols].dtypes)
# Out:
# finalScores_budget        int64
# finalScores_reputation    int64
# finalScores_security      int64
# finalScores_morale        int64
# dtype: object

# %%
#check for GAME OVER in outcomes
game_over_rows = master_df[
    master_df["decisionLog_outcome"].astype(str).str.contains("GAME OVER", case=False, na=False)
]

print("Rows containing GAME OVER:")
print(len(game_over_rows))
print()

game_over_rows[[
    "run_id",
    "source_folder",
    "decision_order",
    "decisionLog_choice",
    "decisionLog_outcome"
]].head(10)
# Out:
# Rows containing GAME OVER:
# 17
#                                 run_id                   source_folder  \
# 190    run_1776088126013_280c4e5e43f4e  CT4010 afternoon decision logs
# 295    run_1776088351584_3619ce98924cc  CT4010 afternoon decision logs
# 353     run_1776088425352_64296be77475  CT4010 afternoon decision logs
# 366   run_1776088472457_0c98f96a50beb8  CT4010 afternoon decision logs
# 648    run_1776075463314_1797effd5d488    CT4010 Morning Decision Logs
# 975   run_1776076382956_e9df293cff1178    CT4010 Morning Decision Logs
# 1016   run_1776076599533_aefc715071823    CT4010 Morning Decision Logs
# 1026  run_1776076634851_8bdcf33b3f7478    CT4010 Morning Decision Logs
# 1037  run_1776174592230_b6cf3ad01c9778  CT5056 Afternoon Decision Logs
# 1052   run_1776174603797_26b878f0f0307  CT5056 Afternoon Decision Logs
#
#       decision_order                       decisionLog_choice  \
# 190               11                   Replace the Server Now
# 295               15                   Replace the Server Now
# 353               13                     Hybrid Storage Model
# 366               13                   Replace the Server Now
# 648               12                     Hybrid Storage Model
# 975               12   Monitoring with Consent and Safeguards
# 1016              11                     Hybrid Storage Model
# 1026              10  Refuse Payment and Restore from Backups
# 1037              11           Strengthen On-Premises Storage
# 1052              15                   Replace the Server Now
#
#                                     decisionLog_outcome
# 190   <strong>Security:</strong> increases because o...
# 295   <strong>Security:</strong> increases because o...
# 353   <strong>Security:</strong> increases moderatel...
# 366   <strong>Security:</strong> increases because o...
# 648   <strong>Security:</strong> increases moderatel...
# 975   <strong>Security:</strong> increases moderatel...
# 1016  <strong>Security:</strong> increases moderatel...
# 1026  <strong>Security:</strong> increases because s...
# 1037  <strong>Security:</strong> increases because l...
# 1052  <strong>Security:</strong> increases because o...

# %%
# final summary of key columns and distributions
print("Unique scenarios:")
print(master_df["decisionLog_scenario"].nunique())
print()

print("Unique choices:")
print(master_df["decisionLog_choice"].nunique())
print()

print("Session times:")
print(master_df["session_time"].value_counts(dropna=False))
print()

print("Module codes:")
print(master_df["module_code"].value_counts(dropna=False))
# Out:
# Unique scenarios:
# 15
#
# Unique choices:
# 45
#
# Session times:
# session_time
# Afternoon        903
# Morning          778
# Not specified    343
# Name: count, dtype: int64
#
# Module codes:
# module_code
# CT4010    1027
# CT5056     654
# CT6033     224
# CT7074     119
# Name: count, dtype: int64

# %% [markdown]
# **Cleaning and Standardisation**

# %%
import html

# make a copy from the already loaded master dataframe
cleaned_df = master_df.copy()

def clean_text(text):
    if pd.isna(text):
        return text

    text = html.unescape(str(text))
    text = text.replace("Â£", "£")
    text = text.replace("Â", "")
    text = text.replace("\r\n", " ").replace("\n", " ").replace("\r", " ").replace("\t", " ")
    text = re.sub(r"\s+", " ", text).strip()
    return text

def clean_outcome_text(text):
    if pd.isna(text):
        return text

    text = html.unescape(str(text))
    text = text.replace("Â£", "£")
    text = text.replace("Â", "")

    # replace html line breaks with readable separators
    text = re.sub(r"(?i)<br\s*/?>", " | ", text)

    # remove all remaining html tags
    text = re.sub(r"<[^>]+>", "", text)

    # remove extra spaces and repeated separators
    text = re.sub(r"\s*\|\s*(\|\s*)+", " | ", text)
    text = re.sub(r"\s+", " ", text).strip(" | ").strip()

    return text

# clean text columns in place
cleaned_df["source_folder"] = cleaned_df["source_folder"].apply(clean_text)
cleaned_df["module_code"] = cleaned_df["module_code"].apply(clean_text)
cleaned_df["session_time"] = cleaned_df["session_time"].apply(clean_text)
cleaned_df["source_file"] = cleaned_df["source_file"].apply(clean_text)

cleaned_df["run_id"] = cleaned_df["run_id"].apply(clean_text)
cleaned_df["sent_at"] = cleaned_df["sent_at"].apply(clean_text)

cleaned_df["decisionLog_scenario"] = cleaned_df["decisionLog_scenario"].apply(clean_text)
cleaned_df["decisionLog_choice"] = cleaned_df["decisionLog_choice"].apply(clean_text)
cleaned_df["decisionLog_outcome"] = cleaned_df["decisionLog_outcome"].apply(clean_outcome_text)
cleaned_df["decisionLog_timestamp"] = cleaned_df["decisionLog_timestamp"].apply(clean_text)

# make sure numeric columns stay numeric
numeric_cols = [
    "finalScores_budget",
    "finalScores_reputation",
    "finalScores_security",
    "finalScores_morale",
    "decisionLog_effects_budget",
    "decisionLog_effects_reputation",
    "decisionLog_effects_security",
    "decisionLog_effects_morale",
    "decision_order",
    "n_decisions"
]

for col in numeric_cols:
    cleaned_df[col] = pd.to_numeric(cleaned_df[col], errors="coerce")

# remove the one suspicious run
suspect_run_id = "run_1777023101559_2dc08da94483f8"
rows_before = cleaned_df.shape[0]

cleaned_df = cleaned_df[cleaned_df["run_id"] != suspect_run_id].copy()

rows_after = cleaned_df.shape[0]
rows_removed = rows_before - rows_after

print("Suspicious run removed:", suspect_run_id)
print("Rows removed:", rows_removed)
print()

# quick checks
print("Unique scenarios:", cleaned_df["decisionLog_scenario"].nunique())
print("Unique choices:", cleaned_df["decisionLog_choice"].nunique())
print()

print("First 3 cleaned outcomes:")
print(cleaned_df["decisionLog_outcome"].head(3))
print()

print("Any remaining Â characters in outcome column:",
      cleaned_df["decisionLog_outcome"].astype(str).str.contains("Â", na=False).sum())
print()

# save cleaned csv
cleaned_file = P.decision_logs_cleaned_dir / "decision_logs_cleaned.csv"
cleaned_df.to_csv(cleaned_file, index=False)

print("Cleaned file saved at:")
print(cleaned_file)
print("Final shape:", cleaned_df.shape)
# Out:
# Suspicious run removed: run_1777023101559_2dc08da94483f8
# Rows removed: 15
#
# Unique scenarios: 15
# Unique choices: 45
#
# First 3 cleaned outcomes:
# 0    Security: remains stable because containment a...
# 1    Security: increases because cloud providers of...
# 2    Security: increases moderately because access ...
# Name: decisionLog_outcome, dtype: object
#
# Any remaining Â characters in outcome column: 0
#
# Cleaned file saved at:
# F:\scenario-based cyber security management simulation\ISMSimulationGame\ISMSimulationGame\Analysis\Data\Decision_Logs\Cleaned\decision_logs_cleaned.csv
# Final shape: (2009, 22)

# %% [markdown]
# **Create scenario_id and choice_id**

# %%
# Create scenario_id and choice_id from the Original Game Code Order

# Safety check: there should be exactly 45 unique scenario-choice pairs
unique_pairs = cleaned_df[["decisionLog_scenario", "decisionLog_choice"]].drop_duplicates().copy()

print("Unique scenario-choice pairs:", unique_pairs.shape[0])
print("Unique scenarios:", unique_pairs["decisionLog_scenario"].nunique())
print("Unique choices:", unique_pairs["decisionLog_choice"].nunique())

assert unique_pairs.shape[0] == 45, "Expected 45 unique scenario-choice pairs."
assert unique_pairs["decisionLog_scenario"].nunique() == 15, "Expected 15 unique scenarios."
# Out:
# Unique scenario-choice pairs: 45
# Unique scenarios: 15
# Unique choices: 45

# %%
# Game structure in Original order from the game code
# Match scenarios using the start of the scenario text
# and assign choices in the Original choice order from the game code

game_structure = [
    {
        "scenario_id": "A",
        "scenario_prefix": "During a routine review of mail gateway logs, you notice a sudden spike in phishing emails",
        "choices": [
            "Immediate University-Wide Warning",
            "Investigate Before Communicating",
            "Block and Monitor Without Warning"
        ]
    },
    {
        "scenario_id": "B",
        "scenario_prefix": "At the start of the academic year, a scheduled vulnerability scan identifies a critical flaw",
        "choices": [
            "Take the System Offline Immediately",
            "Monitor and Delay Action",
            "Apply Temporary Mitigations"
        ]
    },
    {
        "scenario_id": "C",
        "scenario_prefix": "While reviewing access logs for the assessment submission points on Moodle",
        "choices": [
            "Individual Accounts with MFA",
            "Temporary Sharing with a Deadline",
            "Enforce Individual Accounts"
        ]
    },
    {
        "scenario_id": "D",
        "scenario_prefix": "The IT helpdesk reports that multiple machines in a campus computer lab are showing suspicious pop-ups",
        "choices": [
            "Shut Down the Lab Immediately",
            "Isolate Affected Machines",
            "Keep the Lab Open and Monitor"
        ]
    },
    {
        "scenario_id": "E",
        "scenario_prefix": "A monitoring alert shows that a member of staff has exported an unusually large volume of student data",
        "choices": [
            "Immediate Formal Investigation",
            "Covert Monitoring",
            "Supportive Manager-Led Check-In"
        ]
    },
    {
        "scenario_id": "F",
        "scenario_prefix": "Several shared drives used by academic departments become inaccessible, and users see ransom notes",
        "choices": [
            "Pay the Ransom Quickly",
            "Negotiate While Recovering",
            "Refuse Payment and Restore from Backups"
        ]
    },
    {
        "scenario_id": "G",
        "scenario_prefix": "The university has expanded remote learning and hybrid working, but the current setup relies on basic remote access controls",
        "choices": [
            "Secure Remote Work Upgrade",
            "Keep Current Setup with Advice",
            "Prioritise Convenience Over Security"
        ]
    },
    {
        "scenario_id": "H",
        "scenario_prefix": "A school wants to adopt a new cloud-based learning tool before the next teaching block",
        "choices": [
            "Reject the Tool Entirely",
            "Full Security Assessment Before Approval",
            "Approve with Minimal Review"
        ]
    },
    {
        "scenario_id": "I",
        "scenario_prefix": "An old on-premises server used by the Development and Alumni team stores contact data",
        "choices": [
            "Replace the Server Now",
            "Leave It in Place",
            "Segment and Harden the Server"
        ]
    },
    {
        "scenario_id": "J",
        "scenario_prefix": "A research centre is storing sensitive project data in shared folders that are accessible",
        "choices": [
            "Restrict Access Strictly",
            "Leave Permissions as They Are",
            "Phased Access Review"
        ]
    },
    {
        "scenario_id": "K",
        "scenario_prefix": "A recent cyber incident affecting an internal university service has been contained",
        "choices": [
            "Full Transparent Disclosure",
            "Non-Disclosure",
            "Limited Strategic Disclosure"
        ]
    },
    {
        "scenario_id": "L",
        "scenario_prefix": "Recent phishing simulations show weak staff awareness in several departments",
        "choices": [
            "No New Investment",
            "Optional Training Modules",
            "Mandatory Role-Based Training"
        ]
    },
    {
        "scenario_id": "M",
        "scenario_prefix": "Following concerns about productivity in hybrid working, a senior manager proposes deploying employee monitoring software",
        "choices": [
            "Monitoring with Consent and Safeguards",
            "Full Monitoring Deployment",
            "Reject Monitoring"
        ]
    },
    {
        "scenario_id": "N",
        "scenario_prefix": "An internal review finds that one area of campus still relies on weaker Wi-Fi authentication settings",
        "choices": [
            "Full Authentication Upgrade",
            "Password-Only Improvement",
            "Leave Current Setup"
        ]
    },
    {
        "scenario_id": "O",
        "scenario_prefix": "The university is considering whether to:",
        "choices": [
            "Hybrid Storage Model",
            "Move to Third-Party Cloud",
            "Strengthen On-Premises Storage"
        ]
    }
]

# %%
# Build the reference table from the game order
unique_scenarios = cleaned_df["decisionLog_scenario"].drop_duplicates().tolist()

reference_rows = []

for item in game_structure:
    scenario_id = item["scenario_id"]
    scenario_prefix = item["scenario_prefix"]
    choice_list = item["choices"]

    # match the scenario text from the cleaned dataset
    matches = [s for s in unique_scenarios if s.startswith(scenario_prefix)]

    assert len(matches) == 1, (
        f"Expected exactly 1 scenario match for prefix: {scenario_prefix}\n"
        f"Found {len(matches)} matches."
    )

    scenario_text = matches[0]

    # check the three choices present in the data for this scenario
    observed_choices = unique_pairs.loc[
        unique_pairs["decisionLog_scenario"] == scenario_text,
        "decisionLog_choice"
    ].tolist()

    assert set(observed_choices) == set(choice_list), (
        f"Choice mismatch for scenario {scenario_id}.\n"
        f"Observed: {observed_choices}\n"
        f"Expected: {choice_list}"
    )

    # assign A1, A2, A3 etc. in the ORIGINAL choice order from the game code
    for idx, choice in enumerate(choice_list, start=1):
        reference_rows.append({
            "scenario_id": scenario_id,
            "choice_id": f"{scenario_id}{idx}",
            "decisionLog_scenario": scenario_text,
            "decisionLog_choice": choice
        })

reference_df = pd.DataFrame(reference_rows)

# %%
print("\nReference table shape:")
print(reference_df.shape)

print("\nChoices per scenario_id:")
print(reference_df["scenario_id"].value_counts().sort_index())

print("\nPreview:")
print(reference_df.head(10))

assert reference_df.shape[0] == 45, "Reference table should have 45 rows."
assert reference_df["scenario_id"].nunique() == 15, "Reference table should have 15 scenario IDs."
assert reference_df["choice_id"].nunique() == 45, "Reference table should have 45 unique choice IDs."
# Out:
# Reference table shape:
# (45, 4)
#
# Choices per scenario_id:
# scenario_id
# A    3
# B    3
# C    3
# D    3
# E    3
# F    3
# G    3
# H    3
# I    3
# J    3
# K    3
# L    3
# M    3
# N    3
# O    3
# Name: count, dtype: int64
#
# Preview:
#   scenario_id choice_id                               decisionLog_scenario  \
# 0           A        A1  During a routine review of mail gateway logs, ...
# 1           A        A2  During a routine review of mail gateway logs, ...
# 2           A        A3  During a routine review of mail gateway logs, ...
# 3           B        B1  At the start of the academic year, a scheduled...
# 4           B        B2  At the start of the academic year, a scheduled...
# 5           B        B3  At the start of the academic year, a scheduled...
# 6           C        C1  While reviewing access logs for the assessment...
# 7           C        C2  While reviewing access logs for the assessment...
# 8           C        C3  While reviewing access logs for the assessment...
# 9           D        D1  The IT helpdesk reports that multiple machines...
#
#                     decisionLog_choice
# 0    Immediate University-Wide Warning
# 1     Investigate Before Communicating
# 2    Block and Monitor Without Warning
# 3  Take the System Offline Immediately
# 4             Monitor and Delay Action
# 5          Apply Temporary Mitigations
# 6         Individual Accounts with MFA
# 7    Temporary Sharing with a Deadline
# 8          Enforce Individual Accounts
# 9        Shut Down the Lab Immediately

# %%
# Merge IDs back into the cleaned decision log dataset
# IMPORTANT: merge on scenario + choice only

cleaned_with_ids_df = cleaned_df.merge(
    reference_df,
    on=["decisionLog_scenario", "decisionLog_choice"],
    how="left",
    validate="many_to_one"
)

print("\nShape after merge:")
print(cleaned_with_ids_df.shape)

print("\nMissing scenario_id values:", cleaned_with_ids_df["scenario_id"].isna().sum())
print("Missing choice_id values:", cleaned_with_ids_df["choice_id"].isna().sum())

assert cleaned_with_ids_df["scenario_id"].isna().sum() == 0, "Some rows did not get a scenario_id."
assert cleaned_with_ids_df["choice_id"].isna().sum() == 0, "Some rows did not get a choice_id."

print("\nPreview with IDs:")
print(
    cleaned_with_ids_df[
        ["run_id", "decision_order", "scenario_id", "choice_id", "decisionLog_choice"]
    ].head(10)
)
# Out:
# Shape after merge:
# (2009, 24)
#
# Missing scenario_id values: 0
# Missing choice_id values: 0
#
# Preview with IDs:
#                              run_id  decision_order scenario_id choice_id  \
# 0  run_1776087643609_b1186f57813e18               1           F        F2
# 1  run_1776087643609_b1186f57813e18               2           O        O2
# 2  run_1776087643609_b1186f57813e18               3           J        J3
# 3  run_1776087643609_b1186f57813e18               4           B        B3
# 4  run_1776087643609_b1186f57813e18               5           L        L2
# 5  run_1776087643609_b1186f57813e18               6           A        A1
# 6  run_1776087643609_b1186f57813e18               7           H        H1
# 7  run_1776087643609_b1186f57813e18               8           N        N1
# 8  run_1776087643609_b1186f57813e18               9           G        G2
# 9  run_1776087643609_b1186f57813e18              10           C        C1
#
#                   decisionLog_choice
# 0         Negotiate While Recovering
# 1          Move to Third-Party Cloud
# 2               Phased Access Review
# 3        Apply Temporary Mitigations
# 4          Optional Training Modules
# 5  Immediate University-Wide Warning
# 6           Reject the Tool Entirely
# 7        Full Authentication Upgrade
# 8     Keep Current Setup with Advice
# 9       Individual Accounts with MFA

# %%
# Save outputs

reference_file = P.decision_logs_documentation_dir / "scenario_choice_reference.csv"
cleaned_with_ids_file = P.decision_logs_cleaned_dir / "decision_logs_cleaned_with_ids.csv"

reference_df.to_csv(reference_file, index=False)
cleaned_with_ids_df.to_csv(cleaned_with_ids_file, index=False)

print("\nSaved reference table to:")
print(reference_file)

print("\nSaved cleaned dataset with IDs to:")
print(cleaned_with_ids_file)
# Out:
# Saved reference table to:
# F:\scenario-based cyber security management simulation\ISMSimulationGame\ISMSimulationGame\Analysis\Data\Decision_Logs\Documentation\scenario_choice_reference.csv
#
# Saved cleaned dataset with IDs to:
# F:\scenario-based cyber security management simulation\ISMSimulationGame\ISMSimulationGame\Analysis\Data\Decision_Logs\Cleaned\decision_logs_cleaned_with_ids.csv
